# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasiel17/Crime-Prevention/blob/master/Crime_Prevention_Prediction_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
from keras.preprocessing.image import load_img,img_to_array
from keras.models import load_model

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0103418e-25f0-42b0-b1e1-9e117d8e979e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0103418e-25f0-42b0-b1e1-9e117d8e979e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
longitud, altura = 100, 100
model_g='/content/drive/My Drive/Colab Notebooks/modelo/model_guns.h5'
weights_guns='/content/drive/My Drive/Colab Notebooks/modelo/pesos_guns.h5'

# %%
model_guns = load_model(model_g)
model_guns.load_weights(weights_guns)

# %%
def prediction(file):
    x = load_img(file, target_size=(longitud,altura))
    x = img_to_array(x)
    x = np.expand_dims(x, axis=0)
    arr = model_guns.predict(x) 
    r1 = arr[0]
    respuesta = np.argmax(r1)  

    if (respuesta == 0):
        print ("Arma Blanca")
    elif (respuesta == 1):
        print ("Arma de Fuego")

# %% [markdown]
# #**Pruebas**

# %%
img = cv2.imread('tg20.JPG')
cv2_imshow(img)
prediction('tg20.JPG')
# Out:
# <PIL.Image.Image image mode=RGB size=340x279 at 0x7F213D393F28>
# Arma de Fuego

# %%
img = cv2.imread('k3.jpg')
cv2_imshow(img)
prediction('k3.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F213D388080>
# Arma Blanca
